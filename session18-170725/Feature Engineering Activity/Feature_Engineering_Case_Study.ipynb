# %% [markdown]
# ## Use Heart Disease [Dataset](https://github.com/cksajil/DSAIRP25/blob/main/datasets/heart_disease.csv) and answer the following questions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('heart_disease.csv')

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# 1. Find the top 5 important features to the target column

# %%
corr_matrix = df.corr()
corr_matrix
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# ...

# %%
target_corr = corr_matrix['target'].abs().sort_values(ascending=False)
target_corr
# Out:
# target      1.000000
# oldpeak     0.438441
# exang       0.438029
# cp          0.434854
# thalach     0.422895
# ca          0.382085
# slope       0.345512
# thal        0.337838
# sex         0.279501
# age         0.229324
# trestbps    0.138772
# restecg     0.134468
# chol        0.099966
# fbs         0.041164
# Name: target, dtype: float64

# %%
top_5_features = target_corr[1:6]
print("top 5 most important features related to target is:")
print(top_5_features)
# Out:
# top 5 most important features related to target is:
# oldpeak    0.438441
# exang      0.438029
# cp         0.434854
# thalach    0.422895
# ca         0.382085
# Name: target, dtype: float64

# %% [markdown]
# 2. Perform Box-Cox Transformations to relevant features

# %%
from scipy.stats import boxcox

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
numerical_cols = ['age', 'trestbps', 'chol', 'thalach']

# %%
for col in numerical_cols:
    if (df[col] > 0).all():
        df[col + '_boxcox'], _ = boxcox(df[col])

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target  age_boxcox  trestbps_boxcox  chol_boxcox  \
# ...

# %% [markdown]
# 3. Perform Feature Binning to Age Column and add it as a new column to the dataset

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target  age_boxcox  trestbps_boxcox  chol_boxcox  \
# ...

# %%
age_bins = [0, 20, 30, 55, 70, 100]
age_labels = ['Teens','Youth', 'Middle-Aged', 'Senior', 'VeryOld']

# %%
df['AgeGroup'] = pd.cut(df['age'], bins=age_bins, labels=age_labels, right=False)
display(df)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target  age_boxcox  trestbps_boxcox  chol_boxcox  \
# ...

# %%
print("Feature binning applied to 'age' column. New column is 'AgeGroup'.")
print("Value counts for the new 'AgeGroup' column:")
print(df['AgeGroup'].value_counts())
# Out:
# Feature binning applied to 'age' column. New column is 'AgeGroup'.
# Value counts for the new 'AgeGroup' column:
# AgeGroup
# Senior         515
# Middle-Aged    472
# VeryOld         34
# Youth            4
# Teens            0
# Name: count, dtype: int64

# %% [markdown]
# 4. Find the most orthogonal feature to the 'chol' feature

# %%
chol_corr = corr_matrix['chol'].abs().sort_values()
chol_corr
# Out:
# slope       0.014248
# thalach     0.021772
# fbs         0.026917
# oldpeak     0.064880
# exang       0.067382
# ca          0.074259
# cp          0.081641
# target      0.099966
# thal        0.100244
# trestbps    0.127977
# restecg     0.147410
# sex         0.198258
# age         0.219823
# chol        1.000000
# Name: chol, dtype: float64

# %%
most_orthogonal_feature = chol_corr.index[1]
most_orthogonal_feature
# Out:
# 'thalach'

# %%
print("the most orthogonal feature is :", most_orthogonal_feature)
# Out:
# the most orthogonal feature is : thalach
