# %%
# Assignment 05
# ANN ~  Artificial Neural Networks 
# Date : 12-10-2025

# Done By : JOSHUA DAVID

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import keras_tuner as kt

# %%
df = pd.read_csv('mobile_price_classification.csv')

# %%
print("First 5 rows of the dataset:")
print(df.head())
print("\nDataset Information:")
df.info()
# Out:
# First 5 rows of the dataset:
#    battery_power  bluetooth  clock_speed  dual_sim  front_cam  4G  int_memory  \
# 0            842          0          2.2         0          1   0           7
# 1           1021          1          0.5         1          0   1          53
# 2            563          1          0.5         1          2   1          41
# 3            615          1          2.5         0          0   0          10
# 4           1821          1          1.2         0         13   1          44
#
#    m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.6        188        2  ...         20       756  2549     9     7
# 1    0.7        136        3  ...        905      1988  2631    17     3
# 2    0.9        145        5  ...       1263      1716  2603    11     2
# 3    0.8        131        6  ...       1216      1786  2769    16     8
# 4    0.6        141        2  ...       1208      1212  1411     8     2
#
#    talk_time  three_g  touch_screen  wifi  price_range
# 0         19        0             0     1            1
# 1          7        1             1     0            2
# 2          9        1             1     0            2
# 3         11        1             0     0            2
# 4         15        1             1     0            1
#
# [5 rows x 21 columns]
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   battery_power   2000 non-null   int64
#  1   bluetooth       2000 non-null   int64
#  2   clock_speed     2000 non-null   float64
#  3   dual_sim        2000 non-null   int64
#  4   front_cam       2000 non-null   int64
#  5   4G              2000 non-null   int64
#  6   int_memory      2000 non-null   int64
#  7   m_dep           2000 non-null   float64
#  8   mobile_wt       2000 non-null   int64
#  9   n_cores         2000 non-null   int64
#  10  primary_camera  2000 non-null   int64
#  11  px_height       2000 non-null   int64
#  12  px_width        2000 non-null   int64
#  13  ram             2000 non-null   int64
#  14  sc_h            2000 non-null   int64
#  15  sc_w            2000 non-null   int64
#  16  talk_time       2000 non-null   int64
#  17  three_g         2000 non-null   int64
#  18  touch_screen    2000 non-null   int64
#  19  wifi            2000 non-null   int64
#  20  price_range     2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.3 KB

# %%
n_features = X_train.shape[1]
n_classes = len(np.unique(y_train))

# %%
baseline_model = keras.Sequential([
    keras.layers.Input(shape=(n_features,)),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(n_classes, activation='softmax')
])

# %%
baseline_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

baseline_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 32)             │           672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 4)              │            68 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,268 (4.95 KB)
#  Trainable params: 1,268 (4.95 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = baseline_model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2, 
    verbose=1
)
# Out:
# Epoch 1/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9875 - loss: 0.1016 - val_accuracy: 0.9281 - val_loss: 0.1997
# Epoch 2/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9859 - loss: 0.0977 - val_accuracy: 0.9344 - val_loss: 0.1961
# Epoch 3/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9891 - loss: 0.0920 - val_accuracy: 0.9281 - val_loss: 0.1937
# Epoch 4/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9867 - loss: 0.0870 - val_accuracy: 0.9219 - val_loss: 0.1990
# Epoch 5/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9891 - loss: 0.0845 - val_accuracy: 0.9219 - val_loss: 0.2023
# Epoch 6/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9906 - loss: 0.0791 - val_accuracy: 0.9375 - val_loss: 0.1862
# Epoch 7/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9914 - loss: 0.0747 - val_accuracy: 0.9281 - val_loss: 0.1890
# Epoch 8/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9922 - loss: 0.0713 - val_accuracy: 0.9281 - val_loss: 0.1892
# Epoch 9/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9945 - loss: 0.0684 - val_accuracy: 0.9312 - val_loss: 0.1915
# Epoch 10/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9937 - loss: 0.0657 - val_accuracy: 0.9250 - val_loss: 0.1900
# Epoch 11/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9961 - loss: 0
# Epoch 68/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9187 - val_loss: 0.2566
# Epoch 69/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9219 - val_loss: 0.2510
# Epoch 70/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9187 - val_loss: 0.2565
# Epoch 71/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.9219 - val_loss: 0.2569
# Epoch 72/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9187 - val_loss: 0.2594
# Epoch 73/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.9187 - val_loss: 0.2570
# Epoch 74/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9156 - val_loss: 0.2645
# Epoch 75/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9187 - val_loss: 0.2627
# Epoch 76/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9250 - val_loss: 0.2646
# Epoch 77/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9219 - val_loss: 0.2692
# Epoch 78/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9187 - val_loss: 0.2665
# Epoch 79/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9250 - val_loss: 0.2699
# Epoch 80/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9219 - val_loss: 0.2697
# Epoch 81/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9219 - val_loss: 0.2690
# Epoch 82/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9219 - val_loss: 0.2719
# Epoch 83/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9250 - val_loss: 0.2765
# Epoch 84/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9250 - val_loss: 0.2750
# Epoch 85/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9281 - val_loss: 0.2767
# Epoch 86/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9219 - val_loss: 0.2766
# Epoch 87/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9250 - val_loss: 0.2795
# Epoch 88/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9219 - val_loss: 0.2811
# Epoch 89/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9219 - val_loss: 0.2845
# Epoch 90/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9187 - val_loss: 0.2869
# Epoch 91/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9219 - val_loss: 0.2871
# Epoch 92/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9281 - val_loss: 0.2847
# Epoch 93/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9250 - val_loss: 0.2878
# Epoch 94/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9219 - val_loss: 0.2911
# Epoch 95/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9281 - val_loss: 0.2907
# Epoch 96/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9281 - val_loss: 0.2930
# Epoch 97/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9281 - val_loss: 0.2918
# Epoch 98/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9281 - val_loss: 0.2944
# Epoch 99/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9281 - val_loss: 0.2944
# Epoch 100/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9250 - val_loss: 0.2997

# %%
loss, accuracy = baseline_model.evaluate(X_test, y_test)
print(f"\nBaseline Model Test Accuracy: {accuracy*100:.2f}%")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9250 - loss: 0.2351
#
# Baseline Model Test Accuracy: 92.50%

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(keras.layers.Input(shape=(n_features,)))

    # Tune the number of hidden layers and neurons in each
    for i in range(hp.Int('num_layers', 1, 3)):
        model.add(keras.layers.Dense(
            units=hp.Int(f'units_{i}', min_value=32, max_value=256, step=32),
            activation='relu'
        ))

    model.add(keras.layers.Dense(n_classes, activation='softmax'))

    # Tune the learning rate
    learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
tuner = kt.Hyperband(
    build_model,
    objective='val_accuracy',
    max_epochs=20,
    factor=3,
    directory='keras_tuner_dir',
    project_name='mobile_price'
)

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
print("\nStarting hyperparameter search...")
tuner.search(
    X_train, y_train,
    epochs=50,
    validation_split=0.2,
    callbacks=[stop_early],
    verbose=1 )
# Out:
# Trial 30 Complete [00h 00m 05s]
# val_accuracy: 0.512499988079071
#
# Best val_accuracy So Far: 0.9312499761581421
# Total elapsed time: 00h 01m 30s

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# %%
print(f"""
The hyperparameter search is complete.
- Optimal number of layers: {best_hps.get('num_layers')}
- Optimal learning rate: {best_hps.get('learning_rate')}
""")
# Out:
# The hyperparameter search is complete.
# - Optimal number of layers: 1
# - Optimal learning rate: 0.01

# %%
final_model = tuner.hypermodel.build(best_hps)
final_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 256)            │         5,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,404 (25.02 KB)
#  Trainable params: 6,404 (25.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
print("\nTraining the final, tuned model...")
history_final = final_model.fit(
    X_train, y_train,
    epochs=100, # Train for more epochs with early stopping
    validation_split=0.2,
    callbacks=[stop_early],
    verbose=0
)
# Out:
# Training the final, tuned model...

# %%
final_loss, final_accuracy = final_model.evaluate(X_test, y_test)
print(f"\nFinal Tuned Model Test Accuracy: {final_accuracy*100:.2f}%")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9150 - loss: 0.2134
#
# Final Tuned Model Test Accuracy: 91.50%

# %%
final_model.save('mobile_price_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import pickle
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
# ---- TESTINGGGG

# %%
import numpy as np
import tensorflow as tf
import pickle

loaded_model = tf.keras.models.load_model('mobile_price_model.h5')
with open('scaler.pkl', 'rb') as f:
    loaded_scaler = pickle.load(f)

# battery_power,bluetooth,clock_speed,dual_sim,front_cam,4G,int_memory,m_dep,mobile_wt,n_cores,primary_camera,px_height,px_width,ram,sc_h,sc_w,talk_time,three_g,touch_screen,wifi,price_range

new_phone_features = np.array([[
    1800, 1, 2.8, 1, 16, 1, 64, 0.5, 150, 8, 20, 1400, 1800, 4096, 18, 9, 20, 1, 1, 1
]])

scaled_features = loaded_scaler.transform(new_phone_features)

prediction = loaded_model.predict(scaled_features)
predicted_class = np.argmax(prediction[0])

print(f"The predicted price range for the new mobile is: {predicted_class}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# The predicted price range for the new mobile is: 3
# /home/jodave/Desktop/ICT Acadymy/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
price_labels = {
    0: 'Low Cost',
    1: 'Medium Cost',
    2: 'High Cost',
    3: 'Very High Cost'
}

# %%
loaded_model = tf.keras.models.load_model('mobile_price_model.h5')
with open('scaler.pkl', 'rb') as f:
    loaded_scaler = pickle.load(f)
print("Model and scaler loaded successfully.\n")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model and scaler loaded successfully.

# %%
# battery_power,bluetooth,clock_speed,dual_sim,front_cam,4G,int_memory,m_dep,mobile_wt,n_cores,primary_camera,px_height,px_width,ram,sc_h,sc_w,talk_time,three_g,touch_screen,wifi,price_range

# %%
test_phones = np.array([
    # Test1 A budget-friendly phone
    [1000, 0, 1.2, 1, 2, 0, 16, 0.8, 150, 2, 5, 240, 320, 768, 10, 5, 12, 1, 1, 1],

    # Test 2 A solid mid-range phone
    [1400, 1, 2.0, 1, 8, 1, 64, 0.5, 140, 4, 13, 720, 1280, 2048, 14, 7, 15, 1, 1, 1],

    # Test 3 A high-end phone
    [1800, 1, 2.8, 1, 16, 1, 128, 0.7, 160, 8, 24, 1080, 1920, 4096, 16, 8, 18, 1, 1, 1],

    # Test 4 An ultra-premium flagship phone
    [1950, 1, 3.0, 1, 20, 1, 256, 0.6, 170, 8, 48, 1440, 2560, 8192, 18, 9, 20, 1, 1, 1]
])

# %%
scaled_test_phones = loaded_scaler.transform(test_phones)
# Out:
# /home/jodave/Desktop/ICT Acadymy/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
predictions = loaded_model.predict(scaled_test_phones)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step

# %%
for i, prediction in enumerate(predictions):
    predicted_class = np.argmax(prediction)
    confidence = np.max(prediction)
    label = price_labels[predicted_class]

    print(f"\n--- Test Phone {i+1} ---")
    print(f"Predicted Price Range: '{label}' (Class {predicted_class})")
    print(f"Model Confidence: {confidence*100:.2f}%")
# Out:
# --- Test Phone 1 ---
# Predicted Price Range: 'Low Cost' (Class 0)
# Model Confidence: 100.00%
#
# --- Test Phone 2 ---
# Predicted Price Range: 'High Cost' (Class 2)
# Model Confidence: 74.82%
#
# --- Test Phone 3 ---
# Predicted Price Range: 'Very High Cost' (Class 3)
# Model Confidence: 100.00%
#
# --- Test Phone 4 ---
# Predicted Price Range: 'Very High Cost' (Class 3)
# Model Confidence: 100.00%
